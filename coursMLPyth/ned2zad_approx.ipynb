# %%
import numpy as np
def f(x):
    return np.sin(x/5)*np.exp(x/10)+5*np.exp(-x/2)

# %%
f(1)
# Out:
# 3.2522168652714192

# %%
f(15)
# Out:
# 0.63522141957866562

# %%
# %matplotlib inline

# %%
from matplotlib import pylab as plt
x=np.arange(1,15,0.1)
y=f(x)
plt.plot(x,y)
y1=w[0]+w[1]*x
plt.plot(x,y1)
plt.show()

# %%
a=[[1,1],[1,15]]
b=[f(1),f(15)]
w = np.linalg.solve(a, b)

# %%
w
# Out:
# array([ 3.43914511, -0.18692825])

# %%
w[0]+w[1]*15
# Out:
# 0.63522141957866562

# %%
a=[[1,1,1],[1,8,8**2],[1,15,15**2]]
b=[f(1),f(8),f(15)]
w = np.linalg.solve(a, b)

# %%
plt.plot(x,y)

# plt.plot(x,y1)
y2=w[0]+w[1]*x+w[2]*x**2
plt.plot(x,y2)
plt.show()

# %%
a=[[1,1,1,1],[1,4,4**2,4**3],[1,10,10**2,10**3],[1,15,15**2,15**3]]
b=[f(1),f(4),f(10),f(15)]
w = np.linalg.solve(a, b)
plt.plot(x,y)
plt.plot(x,y2)
# plt.plot(x,y1)
y3=w[0]+w[1]*x+w[2]*x**2+w[3]*x**3
plt.plot(x,y3)
plt.show()
