# %%
import pandas as pd

# %%
fr=pd.DataFrame({'nmb':list(range(10)),'chr':['a']*10})

# %%
fr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
# chr    10 non-null object
# nmb    10 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 240.0+ bytes

# %%
fr=pd.read_csv('data.tsv',header=0,sep='\t')

# %%
fr
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Birth</th>
#       <th>City</th>
#       <th>Position</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Иванов А.А.</td>
#       <td>22.03.1980</td>
#       <td>Москва</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Сорокин И.В.</td>
#       <td>07.08.1965</td>
#       <td>Волгоград</td>
#       <td>инженер</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Белов М.М.</td>
#       <td>13.02.1980</td>
#       <td>Ростов</td>
#       <td>менеджер</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Мельникова Д.С.</td>
# ...

# %%
fr.columns
# Out:
# Index(['Name', 'Birth', 'City', 'Position'], dtype='object')

# %%
fr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
# Name        6 non-null object
# Birth       6 non-null object
# City        6 non-null object
# Position    4 non-null object
# dtypes: object(4)
# memory usage: 272.0+ bytes

# %%
nl={'Name':'Perov','Birth':'22.03.1990'}
fr=fr.append(nl,ignore_index=True)

# %%
fr
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Birth</th>
#       <th>City</th>
#       <th>Position</th>
#       <th>isStd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Иванов А.А.</td>
#       <td>22.03.1980</td>
#       <td>Москва</td>
#       <td>NaN</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Сорокин И.В.</td>
#       <td>07.08.1965</td>
#       <td>Волгоград</td>
#       <td>инженер</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Белов М.М.</td>
#       <td>13.02.1980</td>
#       <td>Ростов</td>
#       <td>менеджер</td>
# ...

# %%
fr['isStd']=[False]*4+[True]*3

# %%
fr.drop([5,6],inplace=True)

# %%
fr
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Birth</th>
#       <th>City</th>
#       <th>Position</th>
#       <th>isStd</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Иванов А.А.</td>
#       <td>22.03.1980</td>
#       <td>Москва</td>
#       <td>NaN</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Сорокин И.В.</td>
#       <td>07.08.1965</td>
#       <td>Волгоград</td>
#       <td>инженер</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Белов М.М.</td>
#       <td>13.02.1980</td>
#       <td>Ростов</td>
#       <td>менеджер</td>
# ...

# %%
fr.drop('isStd',axis=1)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Birth</th>
#       <th>City</th>
#       <th>Position</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Иванов А.А.</td>
#       <td>22.03.1980</td>
#       <td>Москва</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Сорокин И.В.</td>
#       <td>07.08.1965</td>
#       <td>Волгоград</td>
#       <td>инженер</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Белов М.М.</td>
#       <td>13.02.1980</td>
#       <td>Ростов</td>
#       <td>менеджер</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Мельникова Д.С.</td>
# ...

# %%
fr.to_csv('upd_data.csv',sep=',',header=True,index=None)

# %%
fr2=pd.read_csv('data.tsv',sep='\t')

# %%
fr2
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Birth</th>
#       <th>City</th>
#       <th>Position</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Иванов А.А.</td>
#       <td>22.03.1980</td>
#       <td>Москва</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Сорокин И.В.</td>
#       <td>07.08.1965</td>
#       <td>Волгоград</td>
#       <td>инженер</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Белов М.М.</td>
#       <td>13.02.1980</td>
#       <td>Ростов</td>
#       <td>менеджер</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Мельникова Д.С.</td>
# ...

# %%
fr.dtypes
# Out:
# Name        object
# Birth       object
# City        object
# Position    object
# isStd         bool
# dtype: object

# %%
fr2.dtypes
# Out:
# Name                object
# Birth       datetime64[ns]
# City                object
# Position            object
# dtype: object

# %%
fr2.Birth=fr2.Birth.apply(pd.to_datetime)

# %%
fr2
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Birth</th>
#       <th>City</th>
#       <th>Position</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Иванов А.А.</td>
#       <td>1980-03-22</td>
#       <td>Москва</td>
#       <td>рабочий</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Сорокин И.В.</td>
#       <td>1965-07-08</td>
#       <td>Волгоград</td>
#       <td>инженер</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Белов М.М.</td>
#       <td>1980-02-13</td>
#       <td>Ростов</td>
#       <td>менеджер</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Мельникова Д.С.</td>
# ...

# %%
fr2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
# Name        6 non-null object
# Birth       6 non-null datetime64[ns]
# City        6 non-null object
# Position    6 non-null object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 272.0+ bytes

# %%
fr2.fillna('рабочий',inplace=True)

# %%
fr2.Position
# Out:
# 0     рабочий
# 1     инженер
# 2    менеджер
# 3     рабочий
# 4     инженер
# 5      стажер
# Name: Position, dtype: object

# %%
fr2[['Name','Position']]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Position</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Иванов А.А.</td>
#       <td>рабочий</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Сорокин И.В.</td>
#       <td>инженер</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Белов М.М.</td>
#       <td>менеджер</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Мельникова Д.С.</td>
#       <td>рабочий</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Рыбина Е.П.</td>
#       <td>инженер</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Костров С.О.</td>
# ...

# %%
fr2.head(3)
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Birth</th>
#       <th>City</th>
#       <th>Position</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Иванов А.А.</td>
#       <td>1980-03-22</td>
#       <td>Москва</td>
#       <td>рабочий</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Сорокин И.В.</td>
#       <td>1965-07-08</td>
#       <td>Волгоград</td>
#       <td>инженер</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Белов М.М.</td>
#       <td>1980-02-13</td>
#       <td>Ростов</td>
#       <td>менеджер</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
fr2[:3]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Birth</th>
#       <th>City</th>
#       <th>Position</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Иванов А.А.</td>
#       <td>1980-03-22</td>
#       <td>Москва</td>
#       <td>рабочий</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Сорокин И.В.</td>
#       <td>1965-07-08</td>
#       <td>Волгоград</td>
#       <td>инженер</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Белов М.М.</td>
#       <td>1980-02-13</td>
#       <td>Ростов</td>
#       <td>менеджер</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
fr2[:1]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Birth</th>
#       <th>City</th>
#       <th>Position</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Иванов А.А.</td>
#       <td>1980-03-22</td>
#       <td>Москва</td>
#       <td>рабочий</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
fr2.loc[[1,3,5],['Name','City']]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>City</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Сорокин И.В.</td>
#       <td>Волгоград</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Мельникова Д.С.</td>
#       <td>Ростов</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Костров С.О.</td>
#       <td>Москва</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
fr2.iloc[[1,3,5],[0,2]]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>City</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Сорокин И.В.</td>
#       <td>Волгоград</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Мельникова Д.С.</td>
#       <td>Ростов</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Костров С.О.</td>
#       <td>Москва</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
fr2.ix[[1,3,5],['Name','City']]
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>City</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Сорокин И.В.</td>
#       <td>Волгоград</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Мельникова Д.С.</td>
#       <td>Ростов</td>
#     </tr>
#     <tr>
# ...

# %%
fr2.ix[[1,3,5],[0,2]]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>City</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Сорокин И.В.</td>
#       <td>Волгоград</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Мельникова Д.С.</td>
#       <td>Ростов</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Костров С.О.</td>
#       <td>Москва</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
fr2[fr2.Birth>=pd.datetime(1985,1,1)]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Birth</th>
#       <th>City</th>
#       <th>Position</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>Мельникова Д.С.</td>
#       <td>1985-04-15</td>
#       <td>Ростов</td>
#       <td>рабочий</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Рыбина Е.П.</td>
#       <td>1985-11-19</td>
#       <td>Москва</td>
#       <td>инженер</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Костров С.О.</td>
#       <td>1985-05-31</td>
#       <td>Москва</td>
#       <td>стажер</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
fr2
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Birth</th>
#       <th>City</th>
#       <th>Position</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Иванов А.А.</td>
#       <td>1980-03-22</td>
#       <td>Москва</td>
#       <td>рабочий</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Сорокин И.В.</td>
#       <td>1965-07-08</td>
#       <td>Волгоград</td>
#       <td>инженер</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Белов М.М.</td>
#       <td>1980-02-13</td>
#       <td>Ростов</td>
#       <td>менеджер</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Мельникова Д.С.</td>
# ...

# %%
fr2[(fr2.City!='Москва') & (fr2.Birth>=pd.datetime(1985,1,1))]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Birth</th>
#       <th>City</th>
#       <th>Position</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>Мельникова Д.С.</td>
#       <td>1985-04-15</td>
#       <td>Ростов</td>
#       <td>рабочий</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
fr2[(fr2.City=='Москва') | (fr2.Birth>=pd.datetime(1985,1,1))]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Birth</th>
#       <th>City</th>
#       <th>Position</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Иванов А.А.</td>
#       <td>1980-03-22</td>
#       <td>Москва</td>
#       <td>рабочий</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Мельникова Д.С.</td>
#       <td>1985-04-15</td>
#       <td>Ростов</td>
#       <td>рабочий</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Рыбина Е.П.</td>
#       <td>1985-11-19</td>
#       <td>Москва</td>
#       <td>инженер</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Костров С.О.</td>
# ...

# %%
fr2.shape
# Out:
# (6, 4)

# %%
fr2['IsSt']=(False)*6
