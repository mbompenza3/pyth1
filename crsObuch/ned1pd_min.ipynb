# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
os.getcwd()
C://Users//MokhnachevskiyAN//PycharmProjects//pyth1
# Out:
# 'C:\\Users\\MokhnachevskiyAN'

# %%
data = pd.read_csv('C://Users//MokhnachevskiyAN//PycharmProjects//pyth1//crsObuch//weights_heights.csv', index_col='Index')

# %%
data.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Height</th>
#       <th>Weight</th>
#     </tr>
#     <tr>
#       <th>Index</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>65.78331</td>
#       <td>112.9925</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>71.51521</td>
#       <td>136.4873</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>69.39874</td>
#       <td>153.0269</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>68.21660</td>
#       <td>142.3354</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>67.78781</td>
#       <td>144.2971</td>
#     </tr>
# ...

# %%
data.plot(y='Mtr',kind='hist',color='red',title='Ht (inch) distr')

# %%
data.plot(y='Kg',kind='hist',color='blue',title='Wt (pound) distr')

# %%
def make_bmi(height_inch, weight_pound):
    METER_TO_INCH, KILO_TO_POUND = 39.37, 2.20462
    return (weight_pound / KILO_TO_POUND) / \
           (height_inch / METER_TO_INCH) ** 2

# %%
data['BMI'] = data.apply(lambda row: make_bmi(row['Height'], 
                                              row['Weight']), axis=1)

# %%
data.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Height</th>
#       <th>Weight</th>
#       <th>BMI</th>
#     </tr>
#     <tr>
#       <th>Index</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>65.78331</td>
#       <td>112.9925</td>
#       <td>18.357573</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>71.51521</td>
#       <td>136.4873</td>
#       <td>18.762577</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>69.39874</td>
#       <td>153.0269</td>
#       <td>22.338895</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>68.21660</td>
# ...

# %%
g=sns.pairplot(data,vars=['Mtr','Kg'])
g.savefig('pp.png')

# %%
data['Kg']=data['Weight']/2.20462
data['Mtr']=data['Height']/39.37

# %%
def weight_category(weight):
    if weight<120:
        return 1
    elif weight>150:
        return 3
    else:
        return 2

data['weight_cat'] = data['Weight'].apply(weight_category)
# Ваш код здесь

# %%
data.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Height</th>
#       <th>Weight</th>
#       <th>BMI</th>
#       <th>Kg</th>
#       <th>Mtr</th>
#       <th>weight_cat</th>
#     </tr>
#     <tr>
#       <th>Index</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>65.78331</td>
#       <td>112.9925</td>
#       <td>18.357573</td>
#       <td>51.252597</td>
#       <td>1.670899</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>71.51521</td>
#       <td>136.4873</td>
#       <td>18.762577</td>
# ...

# %%
sns.boxplot(y='Kg',x='weight_cat',data=data)

# %%
sns.boxplot(y='Mtr',x='weight_cat',data=data)

# %%
data.plot(x='Weight',y='Height',kind='scatter',color='red',title='Wt (pound) distr')

# %%
def error(data,w0,w1):
    e=(data['Height']-(w0+w1*data['Weight']))
    return (np.linalg.norm(e))**2

# %%
w0,w1=60,0.05
e1=data['Height']-(w0+w1*data['Weight'])

# %%
e1[:5]
# Out:
# Index
# 1    0.133685
# 2    4.690845
# 3    1.747395
# 4    1.099830
# 5    0.572955
# dtype: float64

# %%
error(data,60,0.05)
# Out:
# 138197.37942816931

# %%
error(data,50,0.16)
# Out:
# 225065.24911287762

# %%
x=np.linspace(80,200,1000)
plt.plot(data['Weight'],data['Height'])
y=w0+w1*x
plt.plot(x,y)
y1=50+0.16*x
plt.plot(x,y1)
plt.xlabel('Ves')
plt.ylabel('Rost')

# %%
w1=np.linspace(0.1,0.2,1000)
y=np.zeros((1000,))
for i in range(1000):
    y[i]=error(data,50,w1[i])
plt.plot(w1,y)
plt.xlabel('w1')
plt.ylabel('error')

# %%
min(y)
# Out:
# 79513.198951120328

# %%
k=w1[y.argmin()]

# %%
e1=data['Height']-(50+k*data['Weight'])
e1[:5]
# Out:
# Index
# 1   -0.164580
# 2    2.251237
# 3   -2.199651
# 4   -1.872781
# 5   -2.578447
# dtype: float64

# %%
k
# Out:
# 0.14114114114114115

# %%
from scipy import optimize
def error1(w1):
    e=data['Height']-(50+w1*data['Weight'])
    return (np.linalg.norm(e))**2
k=optimize.minimize_scalar(error1,[-5,5])
# Out:
#      fun: 79512.217286994986
#     nfev: 6
#      nit: 5
#  success: True
#        x: 0.14109203728834352

# %%
x=np.linspace(80,200,1000)
plt.plot(data['Weight'],data['Height'])
y=50+k*x
plt.plot(x,y)
# y1=50+0.16*x
# plt.plot(x,y1)
plt.xlabel('Ves')
plt.ylabel('Rost')

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.gca(projection='3d') # get current axis

# Создаем массивы NumPy с координатами точек по осям X и У. 
# Используем метод meshgrid, при котором по векторам координат 
# создается матрица координат. Задаем нужную функцию Z(x, y).
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
Z = np.sin(np.sqrt(X**2 + Y**2))

# Наконец, используем метод *plot_surface* объекта 
# типа Axes3DSubplot. Также подписываем оси.
surf = ax.plot_surface(X, Y, Z)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %%
fig = plt.figure()
ax = fig.gca(projection='3d') # get current axis
def error2(w0,w1):
    e=data['Height']-(w0+w1*data['Weight'])
    return (np.linalg.norm(e))**2
# Создаем массивы NumPy с координатами точек по осям X и У. 
# Используем метод meshgrid, при котором по векторам координат 
# создается матрица координат. Задаем нужную функцию Z(x, y).
w0 = np.arange(0, 100, 5)
w1 = np.arange(0,1, 0.05)
w0, w1 = np.meshgrid(w0, w1)
Z = error2(w0,w1)

# Наконец, используем метод *plot_surface* объекта 
# типа Axes3DSubplot. Также подписываем оси.
surf = ax.plot_surface(w0, w1, Z)
ax.set_xlabel('w0')
ax.set_ylabel('w1')
ax.set_zlabel('Z')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-46069de02f79> in <module>()
#      10 w1 = np.arange(0,1, 0.05)
#      11 w0, w1 = np.meshgrid(w0, w1)
# ---> 12 Z = error2(w0,w1)
#      13
#      14 # Наконец, используем метод *plot_surface* объекта
#
# <ipython-input-71-46069de02f79> in error2(w0, w1)
#       2 ax = fig.gca(projection='3d') # get current axis
#       3 def error2(w0,w1):
# ----> 4     e=data['Height']-(w0+w1*data['Weight'])
#       5     return (np.linalg.norm(e))**2
#       6 # Создаем массивы NumPy с координатами точек по осям X и У.
#
# C:\ProgramData\Miniconda3\lib\site-packages\pandas\core\ops.py in wrapper(left, right, name, na_op)
#     719                 lvalues = lvalues.values
#     720
# --> 721         result = wrap_results(safe_na_op(lvalues, rvalues))
#     722         return construct_result(
#     723             left,
#
# ...

# %%
def error3(w):
    e=data['Height']-(w[0]+w[1]*data['Weight'])
    return (np.linalg.norm(e))**2

# %%
k=optimize.minimize(error3,(0,0),method='L-BFGS-B',bounds=((-100,100),(-5,5)))

# %%
k.x
# Out:
# array([ 57.57174741,   0.08200671])

# %%
x=np.linspace(80,200,1000)
plt.plot(data['Weight'],data['Height'])
y=k.x[0]+k.x[1]*x
plt.plot(x,y)
# y1=50+0.16*x
# plt.plot(x,y1)
plt.xlabel('Ves')
plt.ylabel('Rost')

# %%
k.x[0]+80*k.x[1]
# Out:
# 64.132284193684526

# %%
k.x[0]+200*k.x[1]
# Out:
# 73.973089367691898
